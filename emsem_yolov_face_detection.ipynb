# %%
import os
import shutil
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Model/yolov5l.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Model/yolov5l.zip, /content/drive/MyDrive/Model/yolov5l.zip.zip or /content/drive/MyDrive/Model/yolov5l.zip.ZIP.

# %%
# !unzip /content/drive/MyDrive/yolov5s_results2.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/yolov5s_results2.zip, /content/drive/MyDrive/yolov5s_results2.zip.zip or /content/drive/MyDrive/yolov5s_results2.zip.ZIP.

# %%
# !gdown --id 1KGz0GD8IdCnt6EWwUvHhwjqZJxByA9L8
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1KGz0GD8IdCnt6EWwUvHhwjqZJxByA9L8
# To: /content/picyolo5.zip
# 100% 112M/112M [00:00<00:00, 169MB/s]

# %%
# !unzip /content/picyolo5.zip
# Out:
# Archive:  /content/picyolo5.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/00z_jpg.rf.11b6032bc84b11e02379b50cc7ebc6e3.jpg
#  extracting: test/images/08nba-stein-1-mediumSquareAt3X-v2_jpg.rf.e2e320772d425805d95fb6647f09c747.jpg
#  extracting: test/images/104847301-GettyImages-869615186-stephen-curry_jpg.rf.19a86e15a6998f1e16d2496a68f258d0.jpg
#  extracting: test/images/1124931784-jpg-0_jpg.rf.abf76fb1ebb9bf33d042dad08621dc60.jpg
#  extracting: test/images/1200px-LeBron_James_3409937543_jpg.rf.1bd312ffff7035c3048600a021e34e43.jpg
#  extracting: test/images/1200x0_jpg.rf.5c37b9ea95d18c2b3f4bd0ace1388260.jpg
#  extracting: test/images/1245258353-0_jpg.rf.a5db31c979eb796de3929a993cc2f91d.jpg
#  extracting: test/images/1497262737_jpg.rf.9aef00506bf5d1e22c0c10ff17c76547.jpg
#  extracting: test/images/16027788142004_jpg.rf.a24335aa5e23b70e8c6acaaa33f61574.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %%
# !python val.py --weight /content/drive/MyDrive/Model/YOLOV5m/content/yolov5/runs/train/yolov5s_results/weights/best.pt --data /content/drive/MyDrive/Model/data.yaml
# Out:
# val: data=/content/drive/MyDrive/Model/data.yaml, weights=['/content/drive/MyDrive/Model/YOLOV5m/content/yolov5/runs/train/yolov5s_results/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-169-geef637c Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 21054984 parameters, 0 gradients, 48.5 GFLOPs
#
# Dataset not found ⚠️, missing paths ['/content/yolov5/valid/images']
# Traceback (most recent call last):
#   File "/content/yolov5/val.py", line 409, in <module>
#     main(opt)
#   File "/content/yolov5/val.py", line 380, in main
#     run(**vars(opt))
# ...

# %%
# !python train.py --img 640  --batch 8 --epochs 150 --data /content/data.yaml --cfg /content/yolov5/models/yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# train: weights=, cfg=/content/yolov5/models/yolov5s.yaml, data=/content/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-168-gec2b853 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python train.py --img 640  --batch 8 --epochs 150 --data /content/yolov5/data.yaml --cfg /content/yolov5/models/yolov5m.yaml --weights '' --name yolov5s_results  --cache

# %%
# !python detect.py --weights /content/drive/MyDrive/Model/yolov5l/yolov5/runs/train/yolov5s_results2/weights/best.pt /content/drive/MyDrive/Model/Yolov5s/yolov5/runs/train/yolov5s_results2/weights/best.pt /content/drive/MyDrive/Model/YOLOV5m/content/yolov5/runs/train/yolov5s_results/weights/best.pt  --img 640 --conf 0.25 --save-txt --source  /content/drive/MyDrive/Test2.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/Model/yolov5l/yolov5/runs/train/yolov5s_results2/weights/best.pt', '/content/drive/MyDrive/Model/Yolov5s/yolov5/runs/train/yolov5s_results2/weights/best.pt', '/content/drive/MyDrive/Model/YOLOV5m/content/yolov5/runs/train/yolov5s_results/weights/best.pt'], source=/content/drive/MyDrive/Test2.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7147672 parameters, 0 gradients, 16.2 GFLOPs
# Fusing layers...
# ...

# %%
import os
import pandas as pd

directory = '/content/yolov5/runs/detect/exp/labels'

file_name =[]
file_content = []
for filename in os.listdir(directory):
    if filename.endswith(".txt"):
        file_name.append(filename)
        with open(os.path.join(directory, filename), 'r') as f:
            file_content.append(f.read())


data = {'file_name': file_name, 'file_content': file_content}
df = pd.DataFrame(data)

df
# Out:
#         file_name                             file_content
# 0    TEST_207.txt    3 0.464352 0.54401 0.75463 0.496354\n
# 1     TEST_71.txt  3 0.507407 0.529427 0.809259 0.511979\n
# 2     TEST_89.txt   3 0.50463 0.528906 0.790741 0.503646\n
# 3    TEST_222.txt  3 0.488426 0.572135 0.841667 0.526563\n
# 4     TEST_50.txt  3 0.558796 0.544531 0.871296 0.559896\n
# ..            ...                                      ...
# 235  TEST_240.txt  3 0.425463 0.589323 0.834259 0.535937\n
# 236  TEST_163.txt  3 0.488426 0.540104 0.817593 0.528125\n
# 237   TEST_37.txt   3 0.50787 0.535937 0.778704 0.508333\n
# 238   TEST_83.txt   3 0.546296 0.53099 0.855556 0.523438\n
# 239   TEST_85.txt  3 0.531944 0.531771 0.828704 0.515625\n
#
# [240 rows x 2 columns]

# %%
df['file_content'][0]
# Out:
# '3 0.464352 0.54401 0.75463 0.496354\n'

# %%
df['file_content'] = df['file_content'].str.split().str[:1].str.join(' ')
df
# Out:
#         file_name file_content
# 0    TEST_207.txt            3
# 1     TEST_71.txt            3
# 2     TEST_89.txt            3
# 3    TEST_222.txt            3
# 4     TEST_50.txt            3
# ..            ...          ...
# 235  TEST_240.txt            3
# 236  TEST_163.txt            3
# 237   TEST_37.txt            3
# 238   TEST_83.txt            3
# 239   TEST_85.txt            3
#
# [240 rows x 2 columns]
